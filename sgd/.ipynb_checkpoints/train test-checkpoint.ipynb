# %%
import numpy as np
import matplotlib.pyplot as plt
# Make a prediction with coefficients
import pylab
def predict(row, coefficients):
    yhat = coefficients[0]
    for i in range(len(row)-1):
        yhat += coefficients[i + 1] * row[i] 
    return yhat

# %%
# Estimate linear regression coefficients using stochastic gradient descent

def coefficients_sgd(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    #print(coef)
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train:
            yhat = predict(row, coef)
            error = yhat - row[-1]
            sum_error += (error **2)         
            coef[0] = coef[0] - l_rate * error
            for i in range(len(row)-1):
                coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
        print('>epoch=%d, lrate=%.4f, error=%.3f' % (epoch, l_rate, (sum_error/(2*len(train)))))
        err=(sum_error/(2*len(train)))
    return coef,err

#what 4th line will d0
#trigger to stop
#change alpha find theta0,1
#plot epoch-error
#change theta0,1 init and plot coeff-error

# %%
import csv
from sklearn.model_selection import train_test_split
p=[]
dataset=[]
x=[]
y=[]

trainset=[]
testset=[]
with open('6.txt') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            a = float(row[0])
            x.append(a)
            b = float(row[1])
            y.append(b)
            p =[a,b]
            dataset.append(p)
            
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
l_rate = 0.0001
n_epoch = 1000
for i in range(len(X_train)):
    g=[X_train[i],y_train[i]]
    trainset.append(g)
for i in range(len(X_test)):
    d=[X_test[i],y_test[i]]
    testset.append(d)
coef,err = coefficients_sgd(trainset, l_rate, n_epoch)
coef1,err1 = coefficients_sgd(testset, l_rate, n_epoch)
print("Coef of train",coef)
print("Coef of test",coef1)
print("Cost of Trainset is",err)
print("Cost of Testset is",err1)
# Out:
# >epoch=0, lrate=0.0001, error=122.164
# >epoch=1, lrate=0.0001, error=28.679
# >epoch=2, lrate=0.0001, error=20.590
# >epoch=3, lrate=0.0001, error=19.825
# >epoch=4, lrate=0.0001, error=19.655
# >epoch=5, lrate=0.0001, error=19.523
# >epoch=6, lrate=0.0001, error=19.392
# >epoch=7, lrate=0.0001, error=19.260
# >epoch=8, lrate=0.0001, error=19.129
# >epoch=9, lrate=0.0001, error=18.999
# >epoch=10, lrate=0.0001, error=18.870
# >epoch=11, lrate=0.0001, error=18.741
# >epoch=12, lrate=0.0001, error=18.614
# >epoch=13, lrate=0.0001, error=18.488
# >epoch=14, lrate=0.0001, error=18.363
# >epoch=15, lrate=0.0001, error=18.238
# >epoch=16, lrate=0.0001, error=18.115
# >epoch=17, lrate=0.0001, error=17.993
# >epoch=18, lrate=0.0001, error=17.871
# >epoch=19, lrate=0.0001, error=17.751
# >epoch=20, lrate=0.0001, error=17.632
# >epoch=21, lrate=0.0001, error=17.513
# >epoch=22, lrate=0.0001, error=17.396
# >epoch=23, lrate=0.0001, error=17.279
# >epoch=24, lrate=0.0001, error=17.164
# >epoch=25, lrate=0.0001, error=17.049
# >epoch=26, lrate=0.0001, error=16.935
# >epoch=27, lrate=0.0001, error=16.822
# >epoch=28, lrate=0.0001, error=16.710
# >epoch=29, lrate=0.0001, error=16.599
# >epoch=30, lrate=0.0001, error=16.489
# >epoch=31, lrate=0.0001, error=16.379
# >epoch=32, lrate=0.0001, error=16.271
# >epoch=33, lrate=0.0001, error=16.163
# >epoch=34, lrate=0.0001, error=16.056
# >epoch=35, lrate=0.0001, error=15.950
# >epoch=36, lrate=0.0001, error=15.845
# >epoch=37, lrate=0.0001, error=15.741
# >epoch=38, lrate=0.0001, error=15.637
# >epoch=39, lrate=0.0001, error=15.535
# >epoch=40, lrate=0.0001, error=15.433
# >epoch=41, lrate=0.0001, error=15.332
# >epoch=42, lrate=0.0001, error=15.232
# >epoch=43, lrate=0.0001, error=15.132
# >epoch=44, lrate=0.0001, error=15.034
# >epoch=45, lrate=0.0001, error=14.936
# >epoch=46, lrate=0.0001, error=14.839
# >epoch=47, lrate=0.0001, error=14.742
# >epoch=48, lrate=0.0001, error=14.647
# >epoch=49, lrate=0.0001, error=14.552
# >epoch=50, lrate=0.0001, error=14.458
# >epoch=51, lrate=0.0001, error=14.365
# >epoch=52, lrate=0.0001, error=14.272
# >epoch=53, lrate=0.0001, error=14.180
# >epoch=54, lrate=0.0001, error=14.089
# >epoch=55, lrate=0.0001, error=13.999
# >epoch=56, lrate=0.0001, error=13.909
# >epoch=57, lrate=0.0001, error=13.820
# >epoch=58, lrate=0.0001, error=13.732
# >epoch=59, lrate=0.0001, error=13.644
# >epoch=60, lrate=0.0001, error=13.558
# >epoch=61, lrate=0.0001, error=13.471
# >epoch=62, lrate=0.0001, error=13.386
# >epoch=63, lrate=0.0001, error=13.301
# >epoch=64, lrate=0.0001, error=13.217
# >epoch=65, lrate=0.0001, error=13.133
# >epoch=66, lrate=0.0001, error=13.051
# >epoch=67, lrate=0.0001, error=12.969
# >epoch=68, lrate=0.0001, error=12.887
# >epoch=69, lrate=0.0001, error=12.806
# >epoch=70, lrate=0.0001, error=12.726
# >epoch=71, lrate=0.0001, error=12.646
# >epoch=72, lrate=0.0001, error=12.567
# >epoch=73, lrate=0.0001, error=12.489
# >epoch=74, lrate=0.0001, error=12.411
# >epoch=75, lrate=0.0001, error=12.334
# >epoch=76, lrate=0.0001, error=12.258
# >epoch=77, lrate=0.0001, error=12.182
# >epoch=78, lrate=0.0001, error=12.107
# >epoch=79, lrate=0.0001, error=12.032
# >epoch=80, lrate=0.0001, error=11.958
# >epoch=81, lrate=0.0001, error=11.885
# >epoch=82, lrate=0.0001, error=11.812
# >epoch=83, lrate=0.0001, error=11.739
# >epoch=84, lrate=0.0001, error=11.668
# >epoch=85, lrate=0.0001, error=11.596
# >epoch=86, lrate=0.0001, error=11.526
# >epoch=87, lrate=0.0001, error=11.456
# >epoch=88, lrate=0.0001, error=11.386
# >epoch=89, lrate=0.0001, error=11.317
# >epoch=90, lrate=0.0001, error=11.249
# >epoch=91, lrate=0.0001, error=11.181
# >epoch=92, lrate=0.0001, error=11.114
# >epoch=93, lrate=0.0001, error=11.047
# >epoch=94, lrate=0.0001, error=10.981
# >epoch=95, lrate=0.0001, error=10.915
# >epoch=96, lrate=0.0001, error=10.850
# >epoch=97, lrate=0.0001, error=10.785
# >epoch=98, lrate=0.0001, error=10.721
# >epoch=99, lrate=0.0001, error=10.657
# >epoch=100, lrate=0.0001, error=10.594
# >epoch=101, lrate=0.0001, error=10.531
# >epoch=102, lrate=0.0001, error=10.469
# >epoch=103, lrate=0.0001, error=10.407
# >epoch=104, lrate=0.0001, error=10.346
# >epoch=105, lrate=0.0001, error=10.285
# >epoch=106, lrate=0.0001, error=10.225
# >epoch=107, lrate=0.0001, error=10.165
# >epoch=108, lrate=0.0001, error=10.106
# >epoch=109, lrate=0.0001, error=10.047
# >epoch=110, lrate=0.0001, error=9.989
# >epoch=111, lrate=0.0001, error=9.931
# >epoch=112, lrate=0.0001, error=9.874
# >epoch=113, lrate=0.0001, error=9.817
# >epoch=114, lrate=0.0001, error=9.760
# >epoch=115, lrate=0.0001, error=9.704
# >epoch=116, lrate=0.0001, error=9.648
# >epoch=117, lrate=0.0001, error=9.593
# >epoch=118, lrate=0.0001, error=9.539
# >epoch=119, lrate=0.0001, error=9.484
# >epoch=120, lrate=0.0001, error=9.430
# >epoch=121, lrate=0.0001, error=9.377
# >epoch=122, lrate=0.0001, error=9.324
# >epoch=123, lrate=0.0001, error=9.271
# >epoch=124, lrate=0.0001, error=9.219
# >epoch=125, lrate=0.0001, error=9.167
# >epoch=126, lrate=0.0001, error=9.116
# >epoch=127, lrate=0.0001, error=9.065
# >epoch=128, lrate=0.0001, error=9.014
# >epoch=129, lrate=0.0001, error=8.964
# >epoch=130, lrate=0.0001, error=8.914
# >epoch=131, lrate=0.0001, error=8.865
# >epoch=132, lrate=0.0001, error=8.816
# >epoch=133, lrate=0.0001, error=8.768
# >epoch=134, lrate=0.0001, error=8.719
# >epoch=135, lrate=0.0001, error=8.671
# >epoch=136, lrate=0.0001, error=8.624
# >epoch=137, lrate=0.0001, error=8.577
# >epoch=138, lrate=0.0001, error=8.530
# >epoch=139, lrate=0.0001, error=8.484
# >epoch=140, lrate=0.0001, error=8.438
# >epoch=141, lrate=0.0001, error=8.392
# >epoch=142, lrate=0.0001, error=8.347
# >epoch=143, lrate=0.0001, error=8.302
# >epoch=144, lrate=0.0001, error=8.258
# >epoch=145, lrate=0.0001, error=8.214
# >epoch=146, lrate=0.0001, error=8.170
# >epoch=147, lrate=0.0001, error=8.126
# >epoch=148, lrate=0.0001, error=8.083
# >epoch=149, lrate=0.0001, error=8.040
# >epoch=150, lrate=0.0001, error=7.998
# >epoch=151, lrate=0.0001, error=7.956
# >epoch=152, lrate=0.0001, error=7.914
# >epoch=153, lrate=0.0001, error=7.873
# >epoch=154, lrate=0.0001, error=7.832
# >epoch=155, lrate=0.0001, error=7.791
# >epoch=156, lrate=0.0001, error=7.750
# >epoch=157, lrate=0.0001, error=7.710
# >epoch=158, lrate=0.0001, error=7.670
# >epoch=159, lrate=0.0001, error=7.631
# >epoch=160, lrate=0.0001, error=7.592
# >epoch=161, lrate=0.0001, error=7.553
# >epoch=162, lrate=0.0001, error=7.514
# >epoch=163, lrate=0.0001, error=7.476
# >epoch=164, lrate=0.0001, error=7.438
# >epoch=165, lrate=0.0001, error=7.400
# >epoch=166, lrate=0.0001, error=7.363
# >epoch=167, lrate=0.0001, error=7.326
# >epoch=168, lrate=0.0001, error=7.289
# >epoch=169, lrate=0.0001, error=7.253
# >epoch=170, lrate=0.0001, error=7.216
# >epoch=171, lrate=0.0001, error=7.180
# >epoch=172, lrate=0.0001, error=7.145
# >epoch=173, lrate=0.0001, error=7.110
# >epoch=174, lrate=0.0001, error=7.074
# >epoch=175, lrate=0.0001, error=7.040
# >epoch=176, lrate=0.0001, error=7.005
# >epoch=177, lrate=0.0001, error=6.971
# >epoch=178, lrate=0.0001, error=6.937
# >epoch=179, lrate=0.0001, error=6.903
# >epoch=180, lrate=0.0001, error=6.870
# >epoch=181, lrate=0.0001, error=6.837
# >epoch=182, lrate=0.0001, error=6.804
# >epoch=183, lrate=0.0001, error=6.771
# >epoch=184, lrate=0.0001, error=6.739
# >epoch=185, lrate=0.0001, error=6.707
# >epoch=186, lrate=0.0001, error=6.675
# >epoch=187, lrate=0.0001, error=6.643
# >epoch=188, lrate=0.0001, error=6.612
# >epoch=189, lrate=0.0001, error=6.581
# >epoch=190, lrate=0.0001, error=6.550
# >epoch=191, lrate=0.0001, error=6.519
# >epoch=192, lrate=0.0001, error=6.489
# >epoch=193, lrate=0.0001, error=6.459
# >epoch=194, lrate=0.0001, error=6.429
# >epoch=195, lrate=0.0001, error=6.399
# >epoch=196, lrate=0.0001, error=6.370
# >epoch=197, lrate=0.0001, error=6.340
# >epoch=198, lrate=0.0001, error=6.311
# >epoch=199, lrate=0.0001, error=6.283
# >epoch=200, lrate=0.0001, error=6.254
# >epoch=201, lrate=0.0001, error=6.226
# >epoch=202, lrate=0.0001, error=6.198
# >epoch=203, lrate=0.0001, error=6.170
# >epoch=204, lrate=0.0001, error=6.142
# >epoch=205, lrate=0.0001, error=6.115
# >epoch=206, lrate=0.0001, error=6.088
# >epoch=207, lrate=0.0001, error=6.061
# >epoch=208, lrate=0.0001, error=6.034
# >epoch=209, lrate=0.0001, error=6.008
# >epoch=210, lrate=0.0001, error=5.981
# >epoch=211, lrate=0.0001, error=5.955
# >epoch=212, lrate=0.0001, error=5.929
# >epoch=213, lrate=0.0001, error=5.903
# >epoch=214, lrate=0.0001, error=5.878
# >epoch=215, lrate=0.0001, error=5.853
# >epoch=216, lrate=0.0001, error=5.828
# >epoch=217, lrate=0.0001, error=5.803
# >epoch=218, lrate=0.0001, error=5.778
# >epoch=219, lrate=0.0001, error=5.753
# >epoch=220, lrate=0.0001, error=5.729
# >epoch=221, lrate=0.0001, error=5.705
# >epoch=222, lrate=0.0001, error=5.681
# >epoch=223, lrate=0.0001, error=5.657
# >epoch=224, lrate=0.0001, error=5.634
# >epoch=225, lrate=0.0001, error=5.610
# >epoch=226, lrate=0.0001, error=5.587
# >epoch=227, lrate=0.0001, error=5.564
# >epoch=228, lrate=0.0001, error=5.541
# >epoch=229, lrate=0.0001, error=5.519
# >epoch=230, lrate=0.0001, error=5.496
# >epoch=231, lrate=0.0001, error=5.474
# >epoch=232, lrate=0.0001, error=5.452
# >epoch=233, lrate=0.0001, error=5.430
# >epoch=234, lrate=0.0001, error=5.408
# >epoch=235, lrate=0.0001, error=5.387
# >epoch=236, lrate=0.0001, error=5.365
# >epoch=237, lrate=0.0001, error=5.344
# >epoch=238, lrate=0.0001, error=5.323
# >epoch=239, lrate=0.0001, error=5.302
# >epoch=240, lrate=0.0001, error=5.281
# >epoch=241, lrate=0.0001, error=5.261
# >epoch=242, lrate=0.0001, error=5.240
# >epoch=243, lrate=0.0001, error=5.220
# >epoch=244, lrate=0.0001, error=5.200
# >epoch=245, lrate=0.0001, error=5.180
# >epoch=246, lrate=0.0001, error=5.160
# >epoch=247, lrate=0.0001, error=5.141
# >epoch=248, lrate=0.0001, error=5.121
# >epoch=249, lrate=0.0001, error=5.102
# >epoch=250, lrate=0.0001, error=5.083
# >epoch=251, lrate=0.0001, error=5.064
# >epoch=252, lrate=0.0001, error=5.045
# >epoch=253, lrate=0.0001, error=5.026
# >epoch=254, lrate=0.0001, error=5.008
# >epoch=255, lrate=0.0001, error=4.989
# >epoch=256, lrate=0.0001, error=4.971
# >epoch=257, lrate=0.0001, error=4.953
# >epoch=258, lrate=0.0001, error=4.935
# >epoch=259, lrate=0.0001, error=4.917
# >epoch=260, lrate=0.0001, error=4.899
# >epoch=261, lrate=0.0001, error=4.882
# >epoch=262, lrate=0.0001, error=4.864
# >epoch=263, lrate=0.0001, error=4.847
# >epoch=264, lrate=0.0001, error=4.830
# >epoch=265, lrate=0.0001, error=4.813
# >epoch=266, lrate=0.0001, error=4.796
# >epoch=267, lrate=0.0001, error=4.779
# >epoch=268, lrate=0.0001, error=4.763
# >epoch=269, lrate=0.0001, error=4.746
# >epoch=270, lrate=0.0001, error=4.730
# >epoch=271, lrate=0.0001, error=4.714
# >epoch=272, lrate=0.0001, error=4.698
# >epoch=273, lrate=0.0001, error=4.682
# >epoch=274, lrate=0.0001, error=4.666
# >epoch=275, lrate=0.0001, error=4.650
# >epoch=276, lrate=0.0001, error=4.635
# >epoch=277, lrate=0.0001, error=4.619
# >epoch=278, lrate=0.0001, error=4.604
# >epoch=279, lrate=0.0001, error=4.589
# >epoch=280, lrate=0.0001, error=4.574
# >epoch=281, lrate=0.0001, error=4.559
# >epoch=282, lrate=0.0001, error=4.544
# >epoch=283, lrate=0.0001, error=4.529
# >epoch=284, lrate=0.0001, error=4.514
# >epoch=285, lrate=0.0001, error=4.500
# >epoch=286, lrate=0.0001, error=4.486
# >epoch=287, lrate=0.0001, error=4.471
# >epoch=288, lrate=0.0001, error=4.457
# >epoch=289, lrate=0.0001, error=4.443
# >epoch=290, lrate=0.0001, error=4.429
# >epoch=291, lrate=0.0001, error=4.415
# >epoch=292, lrate=0.0001, error=4.402
# >epoch=293, lrate=0.0001, error=4.388
# >epoch=294, lrate=0.0001, error=4.374
# >epoch=295, lrate=0.0001, error=4.361
# >epoch=296, lrate=0.0001, error=4.348
# >epoch=297, lrate=0.0001, error=4.335
# >epoch=298, lrate=0.0001, error=4.322
# >epoch=299, lrate=0.0001, error=4.309
# >epoch=300, lrate=0.0001, error=4.296
# >epoch=301, lrate=0.0001, error=4.283
# >epoch=302, lrate=0.0001, error=4.270
# >epoch=303, lrate=0.0001, error=4.258
# >epoch=304, lrate=0.0001, error=4.245
# >epoch=305, lrate=0.0001, error=4.233
# >epoch=306, lrate=0.0001, error=4.221
# >epoch=307, lrate=0.0001, error=4.208
# >epoch=308, lrate=0.0001, error=4.196
# >epoch=309, lrate=0.0001, error=4.184
# >epoch=310, lrate=0.0001, error=4.173
# >epoch=311, lrate=0.0001, error=4.161
# >epoch=312, lrate=0.0001, error=4.149
# >epoch=313, lrate=0.0001, error=4.137
# >epoch=314, lrate=0.0001, error=4.126
# >epoch=315, lrate=0.0001, error=4.115
# >epoch=316, lrate=0.0001, error=4.103
# >epoch=317, lrate=0.0001, error=4.092
# >epoch=318, lrate=0.0001, error=4.081
# >epoch=319, lrate=0.0001, error=4.070
# >epoch=320, lrate=0.0001, error=4.059
# >epoch=321, lrate=0.0001, error=4.048
# >epoch=322, lrate=0.0001, error=4.037
# >epoch=323, lrate=0.0001, error=4.026
# >epoch=324, lrate=0.0001, error=4.016
# >epoch=325, lrate=0.0001, error=4.005
# >epoch=326, lrate=0.0001, error=3.995
# >epoch=327, lrate=0.0001, error=3.984
# >epoch=328, lrate=0.0001, error=3.974
# >epoch=329, lrate=0.0001, error=3.964
# >epoch=330, lrate=0.0001, error=3.954
# >epoch=331, lrate=0.0001, error=3.944
# >epoch=332, lrate=0.0001, error=3.934
# >epoch=333, lrate=0.0001, error=3.924
# >epoch=334, lrate=0.0001, error=3.914
# >epoch=335, lrate=0.0001, error=3.904
# >epoch=336, lrate=0.0001, error=3.895
# >epoch=337, lrate=0.0001, error=3.885
# >epoch=338, lrate=0.0001, error=3.875
# >epoch=339, lrate=0.0001, error=3.866
# >epoch=340, lrate=0.0001, error=3.857
# >epoch=341, lrate=0.0001, error=3.847
# >epoch=342, lrate=0.0001, error=3.838
# >epoch=343, lrate=0.0001, error=3.829
# >epoch=344, lrate=0.0001, error=3.820
# >epoch=345, lrate=0.0001, error=3.811
# >epoch=346, lrate=0.0001, error=3.802
# >epoch=347, lrate=0.0001, error=3.793
# >epoch=348, lrate=0.0001, error=3.784
# >epoch=349, lrate=0.0001, error=3.776
# >epoch=350, lrate=0.0001, error=3.767
# >epoch=351, lrate=0.0001, error=3.758
# >epoch=352, lrate=0.0001, error=3.750
# >epoch=353, lrate=0.0001, error=3.742
# >epoch=354, lrate=0.0001, error=3.733
# >epoch=355, lrate=0.0001, error=3.725
# >epoch=356, lrate=0.0001, error=3.717
# >epoch=357, lrate=0.0001, error=3.708
# >epoch=358, lrate=0.0001, error=3.700
# >epoch=359, lrate=0.0001, error=3.692
# >epoch=360, lrate=0.0001, error=3.684
# >epoch=361, lrate=0.0001, error=3.676
# >epoch=362, lrate=0.0001, error=3.668
# >epoch=363, lrate=0.0001, error=3.661
# >epoch=364, lrate=0.0001, error=3.653
# >epoch=365, lrate=0.0001, error=3.645
# >epoch=366, lrate=0.0001, error=3.638
# >epoch=367, lrate=0.0001, error=3.630
# >epoch=368, lrate=0.0001, error=3.623
# >epoch=369, lrate=0.0001, error=3.615
# >epoch=370, lrate=0.0001, error=3.608
# >epoch=371, lrate=0.0001, error=3.601
# >epoch=372, lrate=0.0001, error=3.593
# >epoch=373, lrate=0.0001, error=3.586
# >epoch=374, lrate=0.0001, error=3.579
# >epoch=375, lrate=0.0001, error=3.572
# >epoch=376, lrate=0.0001, error=3.565
# >epoch=377, lrate=0.0001, error=3.558
# >epoch=378, lrate=0.0001, error=3.551
# >epoch=379, lrate=0.0001, error=3.544
# >epoch=380, lrate=0.0001, error=3.537
# >epoch=381, lrate=0.0001, error=3.531
# >epoch=382, lrate=0.0001, error=3.524
# >epoch=383, lrate=0.0001, error=3.517
# >epoch=384, lrate=0.0001, error=3.511
# >epoch=385, lrate=0.0001, error=3.504
# >epoch=386, lrate=0.0001, error=3.498
# >epoch=387, lrate=0.0001, error=3.491
# >epoch=388, lrate=0.0001, error=3.485
# >epoch=389, lrate=0.0001, error=3.478
# >epoch=390, lrate=0.0001, error=3.472
# >epoch=391, lrate=0.0001, error=3.466
# >epoch=392, lrate=0.0001, error=3.460
# >epoch=393, lrate=0.0001, error=3.454
# >epoch=394, lrate=0.0001, error=3.447
# >epoch=395, lrate=0.0001, error=3.441
# >epoch=396, lrate=0.0001, error=3.435
# >epoch=397, lrate=0.0001, error=3.429
# >epoch=398, lrate=0.0001, error=3.424
# >epoch=399, lrate=0.0001, error=3.418
# >epoch=400, lrate=0.0001, error=3.412
# >epoch=401, lrate=0.0001, error=3.406
# >epoch=402, lrate=0.0001, error=3.400
# >epoch=403, lrate=0.0001, error=3.395
# >epoch=404, lrate=0.0001, error=3.389
# >epoch=405, lrate=0.0001, error=3.384
# >epoch=406, lrate=0.0001, error=3.378
# >epoch=407, lrate=0.0001, error=3.372
# >epoch=408, lrate=0.0001, error=3.367
# >epoch=409, lrate=0.0001, error=3.362
# >epoch=410, lrate=0.0001, error=3.356
# >epoch=411, lrate=0.0001, error=3.351
# >epoch=412, lrate=0.0001, error=3.346
# >epoch=413, lrate=0.0001, error=3.340
# >epoch=414, lrate=0.0001, error=3.335
# >epoch=415, lrate=0.0001, error=3.330
# >epoch=416, lrate=0.0001, error=3.325
# >epoch=417, lrate=0.0001, error=3.320
# >epoch=418, lrate=0.0001, error=3.315
# >epoch=419, lrate=0.0001, error=3.310
# >epoch=420, lrate=0.0001, error=3.305
# >epoch=421, lrate=0.0001, error=3.300
# >epoch=422, lrate=0.0001, error=3.295
# >epoch=423, lrate=0.0001, error=3.290
# >epoch=424, lrate=0.0001, error=3.286
# >epoch=425, lrate=0.0001, error=3.281
# >epoch=426, lrate=0.0001, error=3.276
# >epoch=427, lrate=0.0001, error=3.271
# >epoch=428, lrate=0.0001, error=3.267
# >epoch=429, lrate=0.0001, error=3.262
# >epoch=430, lrate=0.0001, error=3.258
# >epoch=431, lrate=0.0001, error=3.253
# >epoch=432, lrate=0.0001, error=3.248
# >epoch=433, lrate=0.0001, error=3.244
# >epoch=434, lrate=0.0001, error=3.240
# >epoch=435, lrate=0.0001, error=3.235
# >epoch=436, lrate=0.0001, error=3.231
# >epoch=437, lrate=0.0001, error=3.226
# >epoch=438, lrate=0.0001, error=3.222
# >epoch=439, lrate=0.0001, error=3.218
# >epoch=440, lrate=0.0001, error=3.214
# >epoch=441, lrate=0.0001, error=3.210
# >epoch=442, lrate=0.0001, error=3.205
# >epoch=443, lrate=0.0001, error=3.201
# >epoch=444, lrate=0.0001, error=3.197
# >epoch=445, lrate=0.0001, error=3.193
# >epoch=446, lrate=0.0001, error=3.189
# >epoch=447, lrate=0.0001, error=3.185
# >epoch=448, lrate=0.0001, error=3.181
# >epoch=449, lrate=0.0001, error=3.177
# >epoch=450, lrate=0.0001, error=3.173
# >epoch=451, lrate=0.0001, error=3.169
# >epoch=452, lrate=0.0001, error=3.166
# >epoch=453, lrate=0.0001, error=3.162
# >epoch=454, lrate=0.0001, error=3.158
# >epoch=455, lrate=0.0001, error=3.154
# >epoch=456, lrate=0.0001, error=3.151
# >epoch=457, lrate=0.0001, error=3.147
# >epoch=458, lrate=0.0001, error=3.143
# >epoch=459, lrate=0.0001, error=3.140
# >epoch=460, lrate=0.0001, error=3.136
# >epoch=461, lrate=0.0001, error=3.132
# >epoch=462, lrate=0.0001, error=3.129
# >epoch=463, lrate=0.0001, error=3.125
# >epoch=464, lrate=0.0001, error=3.122
# >epoch=465, lrate=0.0001, error=3.118
# >epoch=466, lrate=0.0001, error=3.115
# >epoch=467, lrate=0.0001, error=3.112
# >epoch=468, lrate=0.0001, error=3.108
# >epoch=469, lrate=0.0001, error=3.105
# >epoch=470, lrate=0.0001, error=3.101
# >epoch=471, lrate=0.0001, error=3.098
# >epoch=472, lrate=0.0001, error=3.095
# >epoch=473, lrate=0.0001, error=3.092
# >epoch=474, lrate=0.0001, error=3.088
# >epoch=475, lrate=0.0001, error=3.085
# >epoch=476, lrate=0.0001, error=3.082
# >epoch=477, lrate=0.0001, error=3.079
# >epoch=478, lrate=0.0001, error=3.076
# >epoch=479, lrate=0.0001, error=3.073
# >epoch=480, lrate=0.0001, error=3.070
# >epoch=481, lrate=0.0001, error=3.067
# >epoch=482, lrate=0.0001, error=3.064
# >epoch=483, lrate=0.0001, error=3.061
# >epoch=484, lrate=0.0001, error=3.058
# >epoch=485, lrate=0.0001, error=3.055
# >epoch=486, lrate=0.0001, error=3.052
# >epoch=487, lrate=0.0001, error=3.049
# >epoch=488, lrate=0.0001, error=3.046
# >epoch=489, lrate=0.0001, error=3.043
# >epoch=490, lrate=0.0001, error=3.040
# >epoch=491, lrate=0.0001, error=3.037
# >epoch=492, lrate=0.0001, error=3.035
# >epoch=493, lrate=0.0001, error=3.032
# >epoch=494, lrate=0.0001, error=3.029
# >epoch=495, lrate=0.0001, error=3.026
# >epoch=496, lrate=0.0001, error=3.024
# >epoch=497, lrate=0.0001, error=3.021
# >epoch=498, lrate=0.0001, error=3.018
# >epoch=499, lrate=0.0001, error=3.016
# >epoch=500, lrate=0.0001, error=3.013
# >epoch=501, lrate=0.0001, error=3.010
# >epoch=502, lrate=0.0001, error=3.008
# >epoch=503, lrate=0.0001, error=3.005
# >epoch=504, lrate=0.0001, error=3.003
# >epoch=505, lrate=0.0001, error=3.000
# >epoch=506, lrate=0.0001, error=2.998
# >epoch=507, lrate=0.0001, error=2.995
# >epoch=508, lrate=0.0001, error=2.993
# >epoch=509, lrate=0.0001, error=2.990
# >epoch=510, lrate=0.0001, error=2.988
# >epoch=511, lrate=0.0001, error=2.986
# >epoch=512, lrate=0.0001, error=2.983
# >epoch=513, lrate=0.0001, error=2.981
# >epoch=514, lrate=0.0001, error=2.978
# >epoch=515, lrate=0.0001, error=2.976
# >epoch=516, lrate=0.0001, error=2.974
# >epoch=517, lrate=0.0001, error=2.972
# >epoch=518, lrate=0.0001, error=2.969
# >epoch=519, lrate=0.0001, error=2.967
# >epoch=520, lrate=0.0001, error=2.965
# >epoch=521, lrate=0.0001, error=2.963
# >epoch=522, lrate=0.0001, error=2.960
# >epoch=523, lrate=0.0001, error=2.958
# >epoch=524, lrate=0.0001, error=2.956
# >epoch=525, lrate=0.0001, error=2.954
# >epoch=526, lrate=0.0001, error=2.952
# >epoch=527, lrate=0.0001, error=2.950
# >epoch=528, lrate=0.0001, error=2.947
# >epoch=529, lrate=0.0001, error=2.945
# >epoch=530, lrate=0.0001, error=2.943
# >epoch=531, lrate=0.0001, error=2.941
# >epoch=532, lrate=0.0001, error=2.939
# >epoch=533, lrate=0.0001, error=2.937
# >epoch=534, lrate=0.0001, error=2.935
# >epoch=535, lrate=0.0001, error=2.933
# >epoch=536, lrate=0.0001, error=2.931
# >epoch=537, lrate=0.0001, error=2.929
# >epoch=538, lrate=0.0001, error=2.927
# >epoch=539, lrate=0.0001, error=2.925
# >epoch=540, lrate=0.0001, error=2.924
# >epoch=541, lrate=0.0001, error=2.922
# >epoch=542, lrate=0.0001, error=2.920
# >epoch=543, lrate=0.0001, error=2.918
# >epoch=544, lrate=0.0001, error=2.916
# >epoch=545, lrate=0.0001, error=2.914
# >epoch=546, lrate=0.0001, error=2.912
# >epoch=547, lrate=0.0001, error=2.911
# >epoch=548, lrate=0.0001, error=2.909
# >epoch=549, lrate=0.0001, error=2.907
# >epoch=550, lrate=0.0001, error=2.905
# >epoch=551, lrate=0.0001, error=2.904
# >epoch=552, lrate=0.0001, error=2.902
# >epoch=553, lrate=0.0001, error=2.900
# >epoch=554, lrate=0.0001, error=2.898
# >epoch=555, lrate=0.0001, error=2.897
# >epoch=556, lrate=0.0001, error=2.895
# >epoch=557, lrate=0.0001, error=2.893
# >epoch=558, lrate=0.0001, error=2.892
# >epoch=559, lrate=0.0001, error=2.890
# >epoch=560, lrate=0.0001, error=2.888
# >epoch=561, lrate=0.0001, error=2.887
# >epoch=562, lrate=0.0001, error=2.885
# >epoch=563, lrate=0.0001, error=2.884
# >epoch=564, lrate=0.0001, error=2.882
# >epoch=565, lrate=0.0001, error=2.881
# >epoch=566, lrate=0.0001, error=2.879
# >epoch=567, lrate=0.0001, error=2.877
# >epoch=568, lrate=0.0001, error=2.876
# >epoch=569, lrate=0.0001, error=2.874
# >epoch=570, lrate=0.0001, error=2.873
# >epoch=571, lrate=0.0001, error=2.871
# >epoch=572, lrate=0.0001, error=2.870
# >epoch=573, lrate=0.0001, error=2.868
# >epoch=574, lrate=0.0001, error=2.867
# >epoch=575, lrate=0.0001, error=2.866
# >epoch=576, lrate=0.0001, error=2.864
# >epoch=577, lrate=0.0001, error=2.863
# >epoch=578, lrate=0.0001, error=2.861
# >epoch=579, lrate=0.0001, error=2.860
# >epoch=580, lrate=0.0001, error=2.859
# >epoch=581, lrate=0.0001, error=2.857
# >epoch=582, lrate=0.0001, error=2.856
# >epoch=583, lrate=0.0001, error=2.854
# >epoch=584, lrate=0.0001, error=2.853
# >epoch=585, lrate=0.0001, error=2.852
# >epoch=586, lrate=0.0001, error=2.850
# >epoch=587, lrate=0.0001, error=2.849
# >epoch=588, lrate=0.0001, error=2.848
# >epoch=589, lrate=0.0001, error=2.847
# >epoch=590, lrate=0.0001, error=2.845
# >epoch=591, lrate=0.0001, error=2.844
# >epoch=592, lrate=0.0001, error=2.843
# >epoch=593, lrate=0.0001, error=2.841
# >epoch=594, lrate=0.0001, error=2.840
# >epoch=595, lrate=0.0001, error=2.839
# >epoch=596, lrate=0.0001, error=2.838
# >epoch=597, lrate=0.0001, error=2.837
# >epoch=598, lrate=0.0001, error=2.835
# >epoch=599, lrate=0.0001, error=2.834
# >epoch=600, lrate=0.0001, error=2.833
# >epoch=601, lrate=0.0001, error=2.832
# >epoch=602, lrate=0.0001, error=2.831
# >epoch=603, lrate=0.0001, error=2.830
# >epoch=604, lrate=0.0001, error=2.828
# >epoch=605, lrate=0.0001, error=2.827
# >epoch=606, lrate=0.0001, error=2.826
# >epoch=607, lrate=0.0001, error=2.825
# >epoch=608, lrate=0.0001, error=2.824
# >epoch=609, lrate=0.0001, error=2.823
# >epoch=610, lrate=0.0001, error=2.822
# >epoch=611, lrate=0.0001, error=2.821
# >epoch=612, lrate=0.0001, error=2.820
# >epoch=613, lrate=0.0001, error=2.818
# >epoch=614, lrate=0.0001, error=2.817
# >epoch=615, lrate=0.0001, error=2.816
# >epoch=616, lrate=0.0001, error=2.815
# >epoch=617, lrate=0.0001, error=2.814
# >epoch=618, lrate=0.0001, error=2.813
# >epoch=619, lrate=0.0001, error=2.812
# >epoch=620, lrate=0.0001, error=2.811
# >epoch=621, lrate=0.0001, error=2.810
# >epoch=622, lrate=0.0001, error=2.809
# >epoch=623, lrate=0.0001, error=2.808
# >epoch=624, lrate=0.0001, error=2.807
# >epoch=625, lrate=0.0001, error=2.806
# >epoch=626, lrate=0.0001, error=2.805
# >epoch=627, lrate=0.0001, error=2.804
# >epoch=628, lrate=0.0001, error=2.803
# >epoch=629, lrate=0.0001, error=2.802
# >epoch=630, lrate=0.0001, error=2.802
# >epoch=631, lrate=0.0001, error=2.801
# >epoch=632, lrate=0.0001, error=2.800
# >epoch=633, lrate=0.0001, error=2.799
# >epoch=634, lrate=0.0001, error=2.798
# >epoch=635, lrate=0.0001, error=2.797
# >epoch=636, lrate=0.0001, error=2.796
# >epoch=637, lrate=0.0001, error=2.795
# >epoch=638, lrate=0.0001, error=2.794
# >epoch=639, lrate=0.0001, error=2.794
# >epoch=640, lrate=0.0001, error=2.793
# >epoch=641, lrate=0.0001, error=2.792
# >epoch=642, lrate=0.0001, error=2.791
# >epoch=643, lrate=0.0001, error=2.790
# >epoch=644, lrate=0.0001, error=2.789
# >epoch=645, lrate=0.0001, error=2.788
# >epoch=646, lrate=0.0001, error=2.788
# >epoch=647, lrate=0.0001, error=2.787
# >epoch=648, lrate=0.0001, error=2.786
# >epoch=649, lrate=0.0001, error=2.785
# >epoch=650, lrate=0.0001, error=2.784
# >epoch=651, lrate=0.0001, error=2.784
# >epoch=652, lrate=0.0001, error=2.783
# >epoch=653, lrate=0.0001, error=2.782
# >epoch=654, lrate=0.0001, error=2.781
# >epoch=655, lrate=0.0001, error=2.781
# >epoch=656, lrate=0.0001, error=2.780
# >epoch=657, lrate=0.0001, error=2.779
# >epoch=658, lrate=0.0001, error=2.778
# >epoch=659, lrate=0.0001, error=2.778
# >epoch=660, lrate=0.0001, error=2.777
# >epoch=661, lrate=0.0001, error=2.776
# >epoch=662, lrate=0.0001, error=2.775
# >epoch=663, lrate=0.0001, error=2.775
# >epoch=664, lrate=0.0001, error=2.774
# >epoch=665, lrate=0.0001, error=2.773
# >epoch=666, lrate=0.0001, error=2.773
# >epoch=667, lrate=0.0001, error=2.772
# >epoch=668, lrate=0.0001, error=2.771
# >epoch=669, lrate=0.0001, error=2.770
# >epoch=670, lrate=0.0001, error=2.770
# >epoch=671, lrate=0.0001, error=2.769
# >epoch=672, lrate=0.0001, error=2.768
# >epoch=673, lrate=0.0001, error=2.768
# >epoch=674, lrate=0.0001, error=2.767
# >epoch=675, lrate=0.0001, error=2.766
# >epoch=676, lrate=0.0001, error=2.766
# >epoch=677, lrate=0.0001, error=2.765
# >epoch=678, lrate=0.0001, error=2.765
# >epoch=679, lrate=0.0001, error=2.764
# >epoch=680, lrate=0.0001, error=2.763
# >epoch=681, lrate=0.0001, error=2.763
# >epoch=682, lrate=0.0001, error=2.762
# >epoch=683, lrate=0.0001, error=2.761
# >epoch=684, lrate=0.0001, error=2.761
# >epoch=685, lrate=0.0001, error=2.760
# >epoch=686, lrate=0.0001, error=2.760
# >epoch=687, lrate=0.0001, error=2.759
# >epoch=688, lrate=0.0001, error=2.758
# >epoch=689, lrate=0.0001, error=2.758
# >epoch=690, lrate=0.0001, error=2.757
# >epoch=691, lrate=0.0001, error=2.757
# >epoch=692, lrate=0.0001, error=2.756
# >epoch=693, lrate=0.0001, error=2.756
# >epoch=694, lrate=0.0001, error=2.755
# >epoch=695, lrate=0.0001, error=2.754
# >epoch=696, lrate=0.0001, error=2.754
# >epoch=697, lrate=0.0001, error=2.753
# >epoch=698, lrate=0.0001, error=2.753
# >epoch=699, lrate=0.0001, error=2.752
# >epoch=700, lrate=0.0001, error=2.752
# >epoch=701, lrate=0.0001, error=2.751
# >epoch=702, lrate=0.0001, error=2.751
# >epoch=703, lrate=0.0001, error=2.750
# >epoch=704, lrate=0.0001, error=2.750
# >epoch=705, lrate=0.0001, error=2.749
# >epoch=706, lrate=0.0001, error=2.749
# >epoch=707, lrate=0.0001, error=2.748
# >epoch=708, lrate=0.0001, error=2.748
# >epoch=709, lrate=0.0001, error=2.747
# >epoch=710, lrate=0.0001, error=2.747
# >epoch=711, lrate=0.0001, error=2.746
# >epoch=712, lrate=0.0001, error=2.746
# >epoch=713, lrate=0.0001, error=2.745
# >epoch=714, lrate=0.0001, error=2.745
# >epoch=715, lrate=0.0001, error=2.744
# >epoch=716, lrate=0.0001, error=2.744
# >epoch=717, lrate=0.0001, error=2.743
# >epoch=718, lrate=0.0001, error=2.743
# >epoch=719, lrate=0.0001, error=2.742
# >epoch=720, lrate=0.0001, error=2.742
# >epoch=721, lrate=0.0001, error=2.741
# >epoch=722, lrate=0.0001, error=2.741
# >epoch=723, lrate=0.0001, error=2.741
# >epoch=724, lrate=0.0001, error=2.740
# >epoch=725, lrate=0.0001, error=2.740
# >epoch=726, lrate=0.0001, error=2.739
# >epoch=727, lrate=0.0001, error=2.739
# >epoch=728, lrate=0.0001, error=2.738
# >epoch=729, lrate=0.0001, error=2.738
# >epoch=730, lrate=0.0001, error=2.738
# >epoch=731, lrate=0.0001, error=2.737
# >epoch=732, lrate=0.0001, error=2.737
# >epoch=733, lrate=0.0001, error=2.736
# >epoch=734, lrate=0.0001, error=2.736
# >epoch=735, lrate=0.0001, error=2.736
# >epoch=736, lrate=0.0001, error=2.735
# >epoch=737, lrate=0.0001, error=2.735
# >epoch=738, lrate=0.0001, error=2.734
# >epoch=739, lrate=0.0001, error=2.734
# >epoch=740, lrate=0.0001, error=2.734
# >epoch=741, lrate=0.0001, error=2.733
# >epoch=742, lrate=0.0001, error=2.733
# >epoch=743, lrate=0.0001, error=2.732
# >epoch=744, lrate=0.0001, error=2.732
# >epoch=745, lrate=0.0001, error=2.732
# >epoch=746, lrate=0.0001, error=2.731
# >epoch=747, lrate=0.0001, error=2.731
# >epoch=748, lrate=0.0001, error=2.731
# >epoch=749, lrate=0.0001, error=2.730
# >epoch=750, lrate=0.0001, error=2.730
# >epoch=751, lrate=0.0001, error=2.729
# >epoch=752, lrate=0.0001, error=2.729
# >epoch=753, lrate=0.0001, error=2.729
# >epoch=754, lrate=0.0001, error=2.728
# >epoch=755, lrate=0.0001, error=2.728
# >epoch=756, lrate=0.0001, error=2.728
# >epoch=757, lrate=0.0001, error=2.727
# >epoch=758, lrate=0.0001, error=2.727
# >epoch=759, lrate=0.0001, error=2.727
# >epoch=760, lrate=0.0001, error=2.726
# >epoch=761, lrate=0.0001, error=2.726
# >epoch=762, lrate=0.0001, error=2.726
# >epoch=763, lrate=0.0001, error=2.725
# >epoch=764, lrate=0.0001, error=2.725
# >epoch=765, lrate=0.0001, error=2.725
# >epoch=766, lrate=0.0001, error=2.724
# >epoch=767, lrate=0.0001, error=2.724
# >epoch=768, lrate=0.0001, error=2.724
# >epoch=769, lrate=0.0001, error=2.724
# >epoch=770, lrate=0.0001, error=2.723
# >epoch=771, lrate=0.0001, error=2.723
# >epoch=772, lrate=0.0001, error=2.723
# >epoch=773, lrate=0.0001, error=2.722
# >epoch=774, lrate=0.0001, error=2.722
# >epoch=775, lrate=0.0001, error=2.722
# >epoch=776, lrate=0.0001, error=2.721
# >epoch=777, lrate=0.0001, error=2.721
# >epoch=778, lrate=0.0001, error=2.721
# >epoch=779, lrate=0.0001, error=2.721
# >epoch=780, lrate=0.0001, error=2.720
# >epoch=781, lrate=0.0001, error=2.720
# >epoch=782, lrate=0.0001, error=2.720
# >epoch=783, lrate=0.0001, error=2.719
# >epoch=784, lrate=0.0001, error=2.719
# >epoch=785, lrate=0.0001, error=2.719
# >epoch=786, lrate=0.0001, error=2.719
# >epoch=787, lrate=0.0001, error=2.718
# >epoch=788, lrate=0.0001, error=2.718
# >epoch=789, lrate=0.0001, error=2.718
# >epoch=790, lrate=0.0001, error=2.718
# >epoch=791, lrate=0.0001, error=2.717
# >epoch=792, lrate=0.0001, error=2.717
# >epoch=793, lrate=0.0001, error=2.717
# >epoch=794, lrate=0.0001, error=2.717
# >epoch=795, lrate=0.0001, error=2.716
# >epoch=796, lrate=0.0001, error=2.716
# >epoch=797, lrate=0.0001, error=2.716
# >epoch=798, lrate=0.0001, error=2.716
# >epoch=799, lrate=0.0001, error=2.715
# >epoch=800, lrate=0.0001, error=2.715
# >epoch=801, lrate=0.0001, error=2.715
# >epoch=802, lrate=0.0001, error=2.715
# >epoch=803, lrate=0.0001, error=2.714
# >epoch=804, lrate=0.0001, error=2.714
# >epoch=805, lrate=0.0001, error=2.714
# >epoch=806, lrate=0.0001, error=2.714
# >epoch=807, lrate=0.0001, error=2.713
# >epoch=808, lrate=0.0001, error=2.713
# >epoch=809, lrate=0.0001, error=2.713
# >epoch=810, lrate=0.0001, error=2.713
# >epoch=811, lrate=0.0001, error=2.713
# >epoch=812, lrate=0.0001, error=2.712
# >epoch=813, lrate=0.0001, error=2.712
# >epoch=814, lrate=0.0001, error=2.712
# >epoch=815, lrate=0.0001, error=2.712
# >epoch=816, lrate=0.0001, error=2.712
# >epoch=817, lrate=0.0001, error=2.711
# >epoch=818, lrate=0.0001, error=2.711
# >epoch=819, lrate=0.0001, error=2.711
# >epoch=820, lrate=0.0001, error=2.711
# >epoch=821, lrate=0.0001, error=2.710
# >epoch=822, lrate=0.0001, error=2.710
# >epoch=823, lrate=0.0001, error=2.710
# >epoch=824, lrate=0.0001, error=2.710
# >epoch=825, lrate=0.0001, error=2.710
# >epoch=826, lrate=0.0001, error=2.709
# >epoch=827, lrate=0.0001, error=2.709
# >epoch=828, lrate=0.0001, error=2.709
# >epoch=829, lrate=0.0001, error=2.709
# >epoch=830, lrate=0.0001, error=2.709
# >epoch=831, lrate=0.0001, error=2.709
# >epoch=832, lrate=0.0001, error=2.708
# >epoch=833, lrate=0.0001, error=2.708
# >epoch=834, lrate=0.0001, error=2.708
# >epoch=835, lrate=0.0001, error=2.708
# >epoch=836, lrate=0.0001, error=2.708
# >epoch=837, lrate=0.0001, error=2.707
# >epoch=838, lrate=0.0001, error=2.707
# >epoch=839, lrate=0.0001, error=2.707
# >epoch=840, lrate=0.0001, error=2.707
# >epoch=841, lrate=0.0001, error=2.707
# >epoch=842, lrate=0.0001, error=2.707
# >epoch=843, lrate=0.0001, error=2.706
# >epoch=844, lrate=0.0001, error=2.706
# >epoch=845, lrate=0.0001, error=2.706
# >epoch=846, lrate=0.0001, error=2.706
# >epoch=847, lrate=0.0001, error=2.706
# >epoch=848, lrate=0.0001, error=2.706
# >epoch=849, lrate=0.0001, error=2.705
# >epoch=850, lrate=0.0001, error=2.705
# >epoch=851, lrate=0.0001, error=2.705
# >epoch=852, lrate=0.0001, error=2.705
# >epoch=853, lrate=0.0001, error=2.705
# >epoch=854, lrate=0.0001, error=2.705
# >epoch=855, lrate=0.0001, error=2.704
# >epoch=856, lrate=0.0001, error=2.704
# >epoch=857, lrate=0.0001, error=2.704
# >epoch=858, lrate=0.0001, error=2.704
# >epoch=859, lrate=0.0001, error=2.704
# >epoch=860, lrate=0.0001, error=2.704
# >epoch=861, lrate=0.0001, error=2.704
# >epoch=862, lrate=0.0001, error=2.703
# >epoch=863, lrate=0.0001, error=2.703
# >epoch=864, lrate=0.0001, error=2.703
# >epoch=865, lrate=0.0001, error=2.703
# >epoch=866, lrate=0.0001, error=2.703
# >epoch=867, lrate=0.0001, error=2.703
# >epoch=868, lrate=0.0001, error=2.703
# >epoch=869, lrate=0.0001, error=2.702
# >epoch=870, lrate=0.0001, error=2.702
# >epoch=871, lrate=0.0001, error=2.702
# >epoch=872, lrate=0.0001, error=2.702
# >epoch=873, lrate=0.0001, error=2.702
# >epoch=874, lrate=0.0001, error=2.702
# >epoch=875, lrate=0.0001, error=2.702
# >epoch=876, lrate=0.0001, error=2.701
# >epoch=877, lrate=0.0001, error=2.701
# >epoch=878, lrate=0.0001, error=2.701
# >epoch=879, lrate=0.0001, error=2.701
# >epoch=880, lrate=0.0001, error=2.701
# >epoch=881, lrate=0.0001, error=2.701
# >epoch=882, lrate=0.0001, error=2.701
# >epoch=883, lrate=0.0001, error=2.701
# >epoch=884, lrate=0.0001, error=2.700
# >epoch=885, lrate=0.0001, error=2.700
# >epoch=886, lrate=0.0001, error=2.700
# >epoch=887, lrate=0.0001, error=2.700
# >epoch=888, lrate=0.0001, error=2.700
# >epoch=889, lrate=0.0001, error=2.700
# >epoch=890, lrate=0.0001, error=2.700
# >epoch=891, lrate=0.0001, error=2.700
# >epoch=892, lrate=0.0001, error=2.699
# >epoch=893, lrate=0.0001, error=2.699
# >epoch=894, lrate=0.0001, error=2.699
# >epoch=895, lrate=0.0001, error=2.699
# >epoch=896, lrate=0.0001, error=2.699
# >epoch=897, lrate=0.0001, error=2.699
# >epoch=898, lrate=0.0001, error=2.699
# >epoch=899, lrate=0.0001, error=2.699
# >epoch=900, lrate=0.0001, error=2.699
# >epoch=901, lrate=0.0001, error=2.698
# >epoch=902, lrate=0.0001, error=2.698
# >epoch=903, lrate=0.0001, error=2.698
# >epoch=904, lrate=0.0001, error=2.698
# >epoch=905, lrate=0.0001, error=2.698
# >epoch=906, lrate=0.0001, error=2.698
# >epoch=907, lrate=0.0001, error=2.698
# >epoch=908, lrate=0.0001, error=2.698
# >epoch=909, lrate=0.0001, error=2.698
# >epoch=910, lrate=0.0001, error=2.698
# >epoch=911, lrate=0.0001, error=2.697
# >epoch=912, lrate=0.0001, error=2.697
# >epoch=913, lrate=0.0001, error=2.697
# >epoch=914, lrate=0.0001, error=2.697
# >epoch=915, lrate=0.0001, error=2.697
# >epoch=916, lrate=0.0001, error=2.697
# >epoch=917, lrate=0.0001, error=2.697
# >epoch=918, lrate=0.0001, error=2.697
# >epoch=919, lrate=0.0001, error=2.697
# >epoch=920, lrate=0.0001, error=2.697
# >epoch=921, lrate=0.0001, error=2.696
# >epoch=922, lrate=0.0001, error=2.696
# >epoch=923, lrate=0.0001, error=2.696
# >epoch=924, lrate=0.0001, error=2.696
# >epoch=925, lrate=0.0001, error=2.696
# >epoch=926, lrate=0.0001, error=2.696
# >epoch=927, lrate=0.0001, error=2.696
# >epoch=928, lrate=0.0001, error=2.696
# >epoch=929, lrate=0.0001, error=2.696
# >epoch=930, lrate=0.0001, error=2.696
# >epoch=931, lrate=0.0001, error=2.696
# >epoch=932, lrate=0.0001, error=2.696
# >epoch=933, lrate=0.0001, error=2.695
# >epoch=934, lrate=0.0001, error=2.695
# >epoch=935, lrate=0.0001, error=2.695
# >epoch=936, lrate=0.0001, error=2.695
# >epoch=937, lrate=0.0001, error=2.695
# >epoch=938, lrate=0.0001, error=2.695
# >epoch=939, lrate=0.0001, error=2.695
# >epoch=940, lrate=0.0001, error=2.695
# >epoch=941, lrate=0.0001, error=2.695
# >epoch=942, lrate=0.0001, error=2.695
# >epoch=943, lrate=0.0001, error=2.695
# >epoch=944, lrate=0.0001, error=2.695
# >epoch=945, lrate=0.0001, error=2.694
# >epoch=946, lrate=0.0001, error=2.694
# >epoch=947, lrate=0.0001, error=2.694
# >epoch=948, lrate=0.0001, error=2.694
# >epoch=949, lrate=0.0001, error=2.694
# >epoch=950, lrate=0.0001, error=2.694
# >epoch=951, lrate=0.0001, error=2.694
# >epoch=952, lrate=0.0001, error=2.694
# >epoch=953, lrate=0.0001, error=2.694
# >epoch=954, lrate=0.0001, error=2.694
# >epoch=955, lrate=0.0001, error=2.694
# >epoch=956, lrate=0.0001, error=2.694
# >epoch=957, lrate=0.0001, error=2.694
# >epoch=958, lrate=0.0001, error=2.694
# >epoch=959, lrate=0.0001, error=2.693
# >epoch=960, lrate=0.0001, error=2.693
# >epoch=961, lrate=0.0001, error=2.693
# >epoch=962, lrate=0.0001, error=2.693
# >epoch=963, lrate=0.0001, error=2.693
# >epoch=964, lrate=0.0001, error=2.693
# >epoch=965, lrate=0.0001, error=2.693
# >epoch=966, lrate=0.0001, error=2.693
# >epoch=967, lrate=0.0001, error=2.693
# >epoch=968, lrate=0.0001, error=2.693
# >epoch=969, lrate=0.0001, error=2.693
# >epoch=970, lrate=0.0001, error=2.693
# >epoch=971, lrate=0.0001, error=2.693
# >epoch=972, lrate=0.0001, error=2.693
# >epoch=973, lrate=0.0001, error=2.693
# >epoch=974, lrate=0.0001, error=2.693
# >epoch=975, lrate=0.0001, error=2.692
# >epoch=976, lrate=0.0001, error=2.692
# >epoch=977, lrate=0.0001, error=2.692
# >epoch=978, lrate=0.0001, error=2.692
# >epoch=979, lrate=0.0001, error=2.692
# >epoch=980, lrate=0.0001, error=2.692
# >epoch=981, lrate=0.0001, error=2.692
# >epoch=982, lrate=0.0001, error=2.692
# >epoch=983, lrate=0.0001, error=2.692
# >epoch=984, lrate=0.0001, error=2.692
# >epoch=985, lrate=0.0001, error=2.692
# >epoch=986, lrate=0.0001, error=2.692
# >epoch=987, lrate=0.0001, error=2.692
# >epoch=988, lrate=0.0001, error=2.692
# >epoch=989, lrate=0.0001, error=2.692
# >epoch=990, lrate=0.0001, error=2.692
# >epoch=991, lrate=0.0001, error=2.692
# >epoch=992, lrate=0.0001, error=2.692
# >epoch=993, lrate=0.0001, error=2.691
# >epoch=994, lrate=0.0001, error=2.691
# >epoch=995, lrate=0.0001, error=2.691
# >epoch=996, lrate=0.0001, error=2.691
# >epoch=997, lrate=0.0001, error=2.691
# >epoch=998, lrate=0.0001, error=2.691
# >epoch=999, lrate=0.0001, error=2.691
# >epoch=0, lrate=0.0001, error=188.806
# >epoch=1, lrate=0.0001, error=75.150
# >epoch=2, lrate=0.0001, error=36.670
# >epoch=3, lrate=0.0001, error=23.589
# >epoch=4, lrate=0.0001, error=19.105
# >epoch=5, lrate=0.0001, error=17.539
# >epoch=6, lrate=0.0001, error=16.968
# >epoch=7, lrate=0.0001, error=16.740
# >epoch=8, lrate=0.0001, error=16.631
# >epoch=9, lrate=0.0001, error=16.565
# >epoch=10, lrate=0.0001, error=16.514
# >epoch=11, lrate=0.0001, error=16.470
# >epoch=12, lrate=0.0001, error=16.429
# >epoch=13, lrate=0.0001, error=16.388
# >epoch=14, lrate=0.0001, error=16.348
# >epoch=15, lrate=0.0001, error=16.309
# >epoch=16, lrate=0.0001, error=16.270
# >epoch=17, lrate=0.0001, error=16.231
# >epoch=18, lrate=0.0001, error=16.192
# >epoch=19, lrate=0.0001, error=16.153
# >epoch=20, lrate=0.0001, error=16.115
# >epoch=21, lrate=0.0001, error=16.076
# >epoch=22, lrate=0.0001, error=16.038
# >epoch=23, lrate=0.0001, error=16.000
# >epoch=24, lrate=0.0001, error=15.962
# >epoch=25, lrate=0.0001, error=15.924
# >epoch=26, lrate=0.0001, error=15.886
# >epoch=27, lrate=0.0001, error=15.848
# >epoch=28, lrate=0.0001, error=15.810
# >epoch=29, lrate=0.0001, error=15.773
# >epoch=30, lrate=0.0001, error=15.735
# >epoch=31, lrate=0.0001, error=15.698
# >epoch=32, lrate=0.0001, error=15.661
# >epoch=33, lrate=0.0001, error=15.623
# >epoch=34, lrate=0.0001, error=15.586
# >epoch=35, lrate=0.0001, error=15.550
# >epoch=36, lrate=0.0001, error=15.513
# >epoch=37, lrate=0.0001, error=15.476
# >epoch=38, lrate=0.0001, error=15.439
# >epoch=39, lrate=0.0001, error=15.403
# >epoch=40, lrate=0.0001, error=15.367
# >epoch=41, lrate=0.0001, error=15.330
# >epoch=42, lrate=0.0001, error=15.294
# >epoch=43, lrate=0.0001, error=15.258
# >epoch=44, lrate=0.0001, error=15.222
# >epoch=45, lrate=0.0001, error=15.186
# >epoch=46, lrate=0.0001, error=15.150
# >epoch=47, lrate=0.0001, error=15.115
# >epoch=48, lrate=0.0001, error=15.079
# >epoch=49, lrate=0.0001, error=15.044
# >epoch=50, lrate=0.0001, error=15.008
# >epoch=51, lrate=0.0001, error=14.973
# >epoch=52, lrate=0.0001, error=14.938
# >epoch=53, lrate=0.0001, error=14.903
# >epoch=54, lrate=0.0001, error=14.868
# >epoch=55, lrate=0.0001, error=14.833
# >epoch=56, lrate=0.0001, error=14.799
# >epoch=57, lrate=0.0001, error=14.764
# >epoch=58, lrate=0.0001, error=14.729
# >epoch=59, lrate=0.0001, error=14.695
# >epoch=60, lrate=0.0001, error=14.661
# >epoch=61, lrate=0.0001, error=14.626
# >epoch=62, lrate=0.0001, error=14.592
# >epoch=63, lrate=0.0001, error=14.558
# >epoch=64, lrate=0.0001, error=14.524
# >epoch=65, lrate=0.0001, error=14.490
# >epoch=66, lrate=0.0001, error=14.457
# >epoch=67, lrate=0.0001, error=14.423
# >epoch=68, lrate=0.0001, error=14.389
# >epoch=69, lrate=0.0001, error=14.356
# >epoch=70, lrate=0.0001, error=14.323
# >epoch=71, lrate=0.0001, error=14.289
# >epoch=72, lrate=0.0001, error=14.256
# >epoch=73, lrate=0.0001, error=14.223
# >epoch=74, lrate=0.0001, error=14.190
# >epoch=75, lrate=0.0001, error=14.157
# >epoch=76, lrate=0.0001, error=14.124
# >epoch=77, lrate=0.0001, error=14.092
# >epoch=78, lrate=0.0001, error=14.059
# >epoch=79, lrate=0.0001, error=14.027
# >epoch=80, lrate=0.0001, error=13.994
# >epoch=81, lrate=0.0001, error=13.962
# >epoch=82, lrate=0.0001, error=13.930
# >epoch=83, lrate=0.0001, error=13.898
# >epoch=84, lrate=0.0001, error=13.866
# >epoch=85, lrate=0.0001, error=13.834
# >epoch=86, lrate=0.0001, error=13.802
# >epoch=87, lrate=0.0001, error=13.770
# >epoch=88, lrate=0.0001, error=13.738
# >epoch=89, lrate=0.0001, error=13.707
# >epoch=90, lrate=0.0001, error=13.675
# >epoch=91, lrate=0.0001, error=13.644
# >epoch=92, lrate=0.0001, error=13.613
# >epoch=93, lrate=0.0001, error=13.581
# >epoch=94, lrate=0.0001, error=13.550
# >epoch=95, lrate=0.0001, error=13.519
# >epoch=96, lrate=0.0001, error=13.488
# >epoch=97, lrate=0.0001, error=13.457
# >epoch=98, lrate=0.0001, error=13.427
# >epoch=99, lrate=0.0001, error=13.396
# >epoch=100, lrate=0.0001, error=13.365
# >epoch=101, lrate=0.0001, error=13.335
# >epoch=102, lrate=0.0001, error=13.304
# >epoch=103, lrate=0.0001, error=13.274
# >epoch=104, lrate=0.0001, error=13.244
# >epoch=105, lrate=0.0001, error=13.214
# >epoch=106, lrate=0.0001, error=13.184
# >epoch=107, lrate=0.0001, error=13.154
# >epoch=108, lrate=0.0001, error=13.124
# >epoch=109, lrate=0.0001, error=13.094
# >epoch=110, lrate=0.0001, error=13.064
# >epoch=111, lrate=0.0001, error=13.035
# >epoch=112, lrate=0.0001, error=13.005
# >epoch=113, lrate=0.0001, error=12.976
# >epoch=114, lrate=0.0001, error=12.946
# >epoch=115, lrate=0.0001, error=12.917
# >epoch=116, lrate=0.0001, error=12.888
# >epoch=117, lrate=0.0001, error=12.859
# >epoch=118, lrate=0.0001, error=12.830
# >epoch=119, lrate=0.0001, error=12.801
# >epoch=120, lrate=0.0001, error=12.772
# >epoch=121, lrate=0.0001, error=12.743
# >epoch=122, lrate=0.0001, error=12.714
# >epoch=123, lrate=0.0001, error=12.686
# >epoch=124, lrate=0.0001, error=12.657
# >epoch=125, lrate=0.0001, error=12.629
# >epoch=126, lrate=0.0001, error=12.600
# >epoch=127, lrate=0.0001, error=12.572
# >epoch=128, lrate=0.0001, error=12.544
# >epoch=129, lrate=0.0001, error=12.516
# >epoch=130, lrate=0.0001, error=12.488
# >epoch=131, lrate=0.0001, error=12.460
# >epoch=132, lrate=0.0001, error=12.432
# >epoch=133, lrate=0.0001, error=12.404
# >epoch=134, lrate=0.0001, error=12.376
# >epoch=135, lrate=0.0001, error=12.349
# >epoch=136, lrate=0.0001, error=12.321
# >epoch=137, lrate=0.0001, error=12.294
# >epoch=138, lrate=0.0001, error=12.266
# >epoch=139, lrate=0.0001, error=12.239
# >epoch=140, lrate=0.0001, error=12.212
# >epoch=141, lrate=0.0001, error=12.185
# >epoch=142, lrate=0.0001, error=12.157
# >epoch=143, lrate=0.0001, error=12.130
# >epoch=144, lrate=0.0001, error=12.104
# >epoch=145, lrate=0.0001, error=12.077
# >epoch=146, lrate=0.0001, error=12.050
# >epoch=147, lrate=0.0001, error=12.023
# >epoch=148, lrate=0.0001, error=11.997
# >epoch=149, lrate=0.0001, error=11.970
# >epoch=150, lrate=0.0001, error=11.944
# >epoch=151, lrate=0.0001, error=11.917
# >epoch=152, lrate=0.0001, error=11.891
# >epoch=153, lrate=0.0001, error=11.865
# >epoch=154, lrate=0.0001, error=11.838
# >epoch=155, lrate=0.0001, error=11.812
# >epoch=156, lrate=0.0001, error=11.786
# >epoch=157, lrate=0.0001, error=11.760
# >epoch=158, lrate=0.0001, error=11.735
# >epoch=159, lrate=0.0001, error=11.709
# >epoch=160, lrate=0.0001, error=11.683
# >epoch=161, lrate=0.0001, error=11.657
# >epoch=162, lrate=0.0001, error=11.632
# >epoch=163, lrate=0.0001, error=11.606
# >epoch=164, lrate=0.0001, error=11.581
# >epoch=165, lrate=0.0001, error=11.556
# >epoch=166, lrate=0.0001, error=11.530
# >epoch=167, lrate=0.0001, error=11.505
# >epoch=168, lrate=0.0001, error=11.480
# >epoch=169, lrate=0.0001, error=11.455
# >epoch=170, lrate=0.0001, error=11.430
# >epoch=171, lrate=0.0001, error=11.405
# >epoch=172, lrate=0.0001, error=11.380
# >epoch=173, lrate=0.0001, error=11.355
# >epoch=174, lrate=0.0001, error=11.331
# >epoch=175, lrate=0.0001, error=11.306
# >epoch=176, lrate=0.0001, error=11.282
# >epoch=177, lrate=0.0001, error=11.257
# >epoch=178, lrate=0.0001, error=11.233
# >epoch=179, lrate=0.0001, error=11.208
# >epoch=180, lrate=0.0001, error=11.184
# >epoch=181, lrate=0.0001, error=11.160
# >epoch=182, lrate=0.0001, error=11.136
# >epoch=183, lrate=0.0001, error=11.112
# >epoch=184, lrate=0.0001, error=11.088
# >epoch=185, lrate=0.0001, error=11.064
# >epoch=186, lrate=0.0001, error=11.040
# >epoch=187, lrate=0.0001, error=11.016
# >epoch=188, lrate=0.0001, error=10.993
# >epoch=189, lrate=0.0001, error=10.969
# >epoch=190, lrate=0.0001, error=10.945
# >epoch=191, lrate=0.0001, error=10.922
# >epoch=192, lrate=0.0001, error=10.898
# >epoch=193, lrate=0.0001, error=10.875
# >epoch=194, lrate=0.0001, error=10.852
# >epoch=195, lrate=0.0001, error=10.828
# >epoch=196, lrate=0.0001, error=10.805
# >epoch=197, lrate=0.0001, error=10.782
# >epoch=198, lrate=0.0001, error=10.759
# >epoch=199, lrate=0.0001, error=10.736
# >epoch=200, lrate=0.0001, error=10.713
# >epoch=201, lrate=0.0001, error=10.690
# >epoch=202, lrate=0.0001, error=10.668
# >epoch=203, lrate=0.0001, error=10.645
# >epoch=204, lrate=0.0001, error=10.622
# >epoch=205, lrate=0.0001, error=10.600
# >epoch=206, lrate=0.0001, error=10.577
# >epoch=207, lrate=0.0001, error=10.555
# >epoch=208, lrate=0.0001, error=10.532
# >epoch=209, lrate=0.0001, error=10.510
# >epoch=210, lrate=0.0001, error=10.488
# >epoch=211, lrate=0.0001, error=10.466
# >epoch=212, lrate=0.0001, error=10.444
# >epoch=213, lrate=0.0001, error=10.421
# >epoch=214, lrate=0.0001, error=10.399
# >epoch=215, lrate=0.0001, error=10.378
# >epoch=216, lrate=0.0001, error=10.356
# >epoch=217, lrate=0.0001, error=10.334
# >epoch=218, lrate=0.0001, error=10.312
# >epoch=219, lrate=0.0001, error=10.290
# >epoch=220, lrate=0.0001, error=10.269
# >epoch=221, lrate=0.0001, error=10.247
# >epoch=222, lrate=0.0001, error=10.226
# >epoch=223, lrate=0.0001, error=10.204
# >epoch=224, lrate=0.0001, error=10.183
# >epoch=225, lrate=0.0001, error=10.162
# >epoch=226, lrate=0.0001, error=10.140
# >epoch=227, lrate=0.0001, error=10.119
# >epoch=228, lrate=0.0001, error=10.098
# >epoch=229, lrate=0.0001, error=10.077
# >epoch=230, lrate=0.0001, error=10.056
# >epoch=231, lrate=0.0001, error=10.035
# >epoch=232, lrate=0.0001, error=10.014
# >epoch=233, lrate=0.0001, error=9.993
# >epoch=234, lrate=0.0001, error=9.973
# >epoch=235, lrate=0.0001, error=9.952
# >epoch=236, lrate=0.0001, error=9.931
# >epoch=237, lrate=0.0001, error=9.911
# >epoch=238, lrate=0.0001, error=9.890
# >epoch=239, lrate=0.0001, error=9.870
# >epoch=240, lrate=0.0001, error=9.849
# >epoch=241, lrate=0.0001, error=9.829
# >epoch=242, lrate=0.0001, error=9.809
# >epoch=243, lrate=0.0001, error=9.789
# >epoch=244, lrate=0.0001, error=9.768
# >epoch=245, lrate=0.0001, error=9.748
# >epoch=246, lrate=0.0001, error=9.728
# >epoch=247, lrate=0.0001, error=9.708
# >epoch=248, lrate=0.0001, error=9.688
# >epoch=249, lrate=0.0001, error=9.668
# >epoch=250, lrate=0.0001, error=9.649
# >epoch=251, lrate=0.0001, error=9.629
# >epoch=252, lrate=0.0001, error=9.609
# >epoch=253, lrate=0.0001, error=9.590
# >epoch=254, lrate=0.0001, error=9.570
# >epoch=255, lrate=0.0001, error=9.550
# >epoch=256, lrate=0.0001, error=9.531
# >epoch=257, lrate=0.0001, error=9.512
# >epoch=258, lrate=0.0001, error=9.492
# ...
# >epoch=584, lrate=0.0001, error=5.411
# >epoch=585, lrate=0.0001, error=5.403
# >epoch=586, lrate=0.0001, error=5.396
# >epoch=587, lrate=0.0001, error=5.388
# >epoch=588, lrate=0.0001, error=5.381
# >epoch=589, lrate=0.0001, error=5.373
# >epoch=590, lrate=0.0001, error=5.366
# >epoch=591, lrate=0.0001, error=5.359
# >epoch=592, lrate=0.0001, error=5.351
# >epoch=593, lrate=0.0001, error=5.344
# >epoch=594, lrate=0.0001, error=5.336
# >epoch=595, lrate=0.0001, error=5.329
# >epoch=596, lrate=0.0001, error=5.322
# >epoch=597, lrate=0.0001, error=5.315
# >epoch=598, lrate=0.0001, error=5.307
# >epoch=599, lrate=0.0001, error=5.300
# >epoch=600, lrate=0.0001, error=5.293
# >epoch=601, lrate=0.0001, error=5.286
# >epoch=602, lrate=0.0001, error=5.279
# >epoch=603, lrate=0.0001, error=5.271
# >epoch=604, lrate=0.0001, error=5.264
# >epoch=605, lrate=0.0001, error=5.257
# >epoch=606, lrate=0.0001, error=5.250
# >epoch=607, lrate=0.0001, error=5.243
# >epoch=608, lrate=0.0001, error=5.236
# >epoch=609, lrate=0.0001, error=5.229
# >epoch=610, lrate=0.0001, error=5.222
# >epoch=611, lrate=0.0001, error=5.215
# >epoch=612, lrate=0.0001, error=5.208
# >epoch=613, lrate=0.0001, error=5.201
# >epoch=614, lrate=0.0001, error=5.194
# >epoch=615, lrate=0.0001, error=5.187
# >epoch=616, lrate=0.0001, error=5.181
# >epoch=617, lrate=0.0001, error=5.174
# >epoch=618, lrate=0.0001, error=5.167
# >epoch=619, lrate=0.0001, error=5.160
# >epoch=620, lrate=0.0001, error=5.153
# >epoch=621, lrate=0.0001, error=5.146
# >epoch=622, lrate=0.0001, error=5.140
# >epoch=623, lrate=0.0001, error=5.133
# >epoch=624, lrate=0.0001, error=5.126
# >epoch=625, lrate=0.0001, error=5.120
# >epoch=626, lrate=0.0001, error=5.113
# >epoch=627, lrate=0.0001, error=5.106
# >epoch=628, lrate=0.0001, error=5.100
# >epoch=629, lrate=0.0001, error=5.093
# >epoch=630, lrate=0.0001, error=5.086
# >epoch=631, lrate=0.0001, error=5.080
# >epoch=632, lrate=0.0001, error=5.073
# >epoch=633, lrate=0.0001, error=5.067
# >epoch=634, lrate=0.0001, error=5.060
# >epoch=635, lrate=0.0001, error=5.054
# >epoch=636, lrate=0.0001, error=5.047
# >epoch=637, lrate=0.0001, error=5.041
# >epoch=638, lrate=0.0001, error=5.034
# >epoch=639, lrate=0.0001, error=5.028
# >epoch=640, lrate=0.0001, error=5.021
# >epoch=641, lrate=0.0001, error=5.015
# >epoch=642, lrate=0.0001, error=5.009
# >epoch=643, lrate=0.0001, error=5.002
# >epoch=644, lrate=0.0001, error=4.996
# >epoch=645, lrate=0.0001, error=4.990
# >epoch=646, lrate=0.0001, error=4.983
# >epoch=647, lrate=0.0001, error=4.977
# >epoch=648, lrate=0.0001, error=4.971
# >epoch=649, lrate=0.0001, error=4.964
# >epoch=650, lrate=0.0001, error=4.958
# >epoch=651, lrate=0.0001, error=4.952
# >epoch=652, lrate=0.0001, error=4.946
# >epoch=653, lrate=0.0001, error=4.940
# >epoch=654, lrate=0.0001, error=4.933
# >epoch=655, lrate=0.0001, error=4.927
# >epoch=656, lrate=0.0001, error=4.921
# >epoch=657, lrate=0.0001, error=4.915
# >epoch=658, lrate=0.0001, error=4.909
# >epoch=659, lrate=0.0001, error=4.903
# >epoch=660, lrate=0.0001, error=4.897
# >epoch=661, lrate=0.0001, error=4.891
# >epoch=662, lrate=0.0001, error=4.885
# >epoch=663, lrate=0.0001, error=4.879
# >epoch=664, lrate=0.0001, error=4.873
# >epoch=665, lrate=0.0001, error=4.867
# >epoch=666, lrate=0.0001, error=4.861
# >epoch=667, lrate=0.0001, error=4.855
# >epoch=668, lrate=0.0001, error=4.849
# >epoch=669, lrate=0.0001, error=4.843
# >epoch=670, lrate=0.0001, error=4.837
# >epoch=671, lrate=0.0001, error=4.831
# >epoch=672, lrate=0.0001, error=4.826
# >epoch=673, lrate=0.0001, error=4.820
# >epoch=674, lrate=0.0001, error=4.814
# >epoch=675, lrate=0.0001, error=4.808
# >epoch=676, lrate=0.0001, error=4.802
# >epoch=677, lrate=0.0001, error=4.797
# >epoch=678, lrate=0.0001, error=4.791
# >epoch=679, lrate=0.0001, error=4.785
# >epoch=680, lrate=0.0001, error=4.779
# >epoch=681, lrate=0.0001, error=4.774
# >epoch=682, lrate=0.0001, error=4.768
# >epoch=683, lrate=0.0001, error=4.762
# >epoch=684, lrate=0.0001, error=4.757
# >epoch=685, lrate=0.0001, error=4.751
# >epoch=686, lrate=0.0001, error=4.745
# >epoch=687, lrate=0.0001, error=4.740
# >epoch=688, lrate=0.0001, error=4.734
# >epoch=689, lrate=0.0001, error=4.729
# >epoch=690, lrate=0.0001, error=4.723
# >epoch=691, lrate=0.0001, error=4.718
# >epoch=692, lrate=0.0001, error=4.712
# >epoch=693, lrate=0.0001, error=4.707
# >epoch=694, lrate=0.0001, error=4.701
# >epoch=695, lrate=0.0001, error=4.696
# >epoch=696, lrate=0.0001, error=4.690
# >epoch=697, lrate=0.0001, error=4.685
# >epoch=698, lrate=0.0001, error=4.679
# >epoch=699, lrate=0.0001, error=4.674
# >epoch=700, lrate=0.0001, error=4.668
# >epoch=701, lrate=0.0001, error=4.663
# >epoch=702, lrate=0.0001, error=4.658
# >epoch=703, lrate=0.0001, error=4.652
# >epoch=704, lrate=0.0001, error=4.647
# >epoch=705, lrate=0.0001, error=4.642
# >epoch=706, lrate=0.0001, error=4.636
# >epoch=707, lrate=0.0001, error=4.631
# >epoch=708, lrate=0.0001, error=4.626
# >epoch=709, lrate=0.0001, error=4.621
# >epoch=710, lrate=0.0001, error=4.615
# >epoch=711, lrate=0.0001, error=4.610
# >epoch=712, lrate=0.0001, error=4.605
# >epoch=713, lrate=0.0001, error=4.600
# >epoch=714, lrate=0.0001, error=4.595
# >epoch=715, lrate=0.0001, error=4.589
# >epoch=716, lrate=0.0001, error=4.584
# >epoch=717, lrate=0.0001, error=4.579
# >epoch=718, lrate=0.0001, error=4.574
# >epoch=719, lrate=0.0001, error=4.569
# >epoch=720, lrate=0.0001, error=4.564
# >epoch=721, lrate=0.0001, error=4.559
# >epoch=722, lrate=0.0001, error=4.554
# >epoch=723, lrate=0.0001, error=4.549
# >epoch=724, lrate=0.0001, error=4.544
# >epoch=725, lrate=0.0001, error=4.539
# >epoch=726, lrate=0.0001, error=4.534
# >epoch=727, lrate=0.0001, error=4.529
# >epoch=728, lrate=0.0001, error=4.524
# >epoch=729, lrate=0.0001, error=4.519
# >epoch=730, lrate=0.0001, error=4.514
# >epoch=731, lrate=0.0001, error=4.509
# >epoch=732, lrate=0.0001, error=4.504
# >epoch=733, lrate=0.0001, error=4.499
# >epoch=734, lrate=0.0001, error=4.494
# >epoch=735, lrate=0.0001, error=4.489
# >epoch=736, lrate=0.0001, error=4.484
# >epoch=737, lrate=0.0001, error=4.479
# >epoch=738, lrate=0.0001, error=4.475
# >epoch=739, lrate=0.0001, error=4.470
# >epoch=740, lrate=0.0001, error=4.465
# >epoch=741, lrate=0.0001, error=4.460
# >epoch=742, lrate=0.0001, error=4.455
# >epoch=743, lrate=0.0001, error=4.451
# >epoch=744, lrate=0.0001, error=4.446
# >epoch=745, lrate=0.0001, error=4.441
# >epoch=746, lrate=0.0001, error=4.436
# >epoch=747, lrate=0.0001, error=4.432
# >epoch=748, lrate=0.0001, error=4.427
# >epoch=749, lrate=0.0001, error=4.422
# >epoch=750, lrate=0.0001, error=4.418
# >epoch=751, lrate=0.0001, error=4.413
# >epoch=752, lrate=0.0001, error=4.408
# >epoch=753, lrate=0.0001, error=4.404
# >epoch=754, lrate=0.0001, error=4.399
# >epoch=755, lrate=0.0001, error=4.395
# >epoch=756, lrate=0.0001, error=4.390
# >epoch=757, lrate=0.0001, error=4.385
# >epoch=758, lrate=0.0001, error=4.381
# >epoch=759, lrate=0.0001, error=4.376
# >epoch=760, lrate=0.0001, error=4.372
# >epoch=761, lrate=0.0001, error=4.367
# >epoch=762, lrate=0.0001, error=4.363
# >epoch=763, lrate=0.0001, error=4.358
# >epoch=764, lrate=0.0001, error=4.354
# >epoch=765, lrate=0.0001, error=4.349
# >epoch=766, lrate=0.0001, error=4.345
# >epoch=767, lrate=0.0001, error=4.340
# >epoch=768, lrate=0.0001, error=4.336
# >epoch=769, lrate=0.0001, error=4.332
# >epoch=770, lrate=0.0001, error=4.327
# >epoch=771, lrate=0.0001, error=4.323
# >epoch=772, lrate=0.0001, error=4.318
# >epoch=773, lrate=0.0001, error=4.314
# >epoch=774, lrate=0.0001, error=4.310
# >epoch=775, lrate=0.0001, error=4.305
# >epoch=776, lrate=0.0001, error=4.301
# >epoch=777, lrate=0.0001, error=4.297
# >epoch=778, lrate=0.0001, error=4.292
# >epoch=779, lrate=0.0001, error=4.288
# >epoch=780, lrate=0.0001, error=4.284
# >epoch=781, lrate=0.0001, error=4.280
# >epoch=782, lrate=0.0001, error=4.275
# >epoch=783, lrate=0.0001, error=4.271
# >epoch=784, lrate=0.0001, error=4.267
# >epoch=785, lrate=0.0001, error=4.263
# >epoch=786, lrate=0.0001, error=4.258
# >epoch=787, lrate=0.0001, error=4.254
# >epoch=788, lrate=0.0001, error=4.250
# >epoch=789, lrate=0.0001, error=4.246
# >epoch=790, lrate=0.0001, error=4.242
# >epoch=791, lrate=0.0001, error=4.238
# >epoch=792, lrate=0.0001, error=4.233
# >epoch=793, lrate=0.0001, error=4.229
# >epoch=794, lrate=0.0001, error=4.225
# >epoch=795, lrate=0.0001, error=4.221
# >epoch=796, lrate=0.0001, error=4.217
# >epoch=797, lrate=0.0001, error=4.213
# >epoch=798, lrate=0.0001, error=4.209
# >epoch=799, lrate=0.0001, error=4.205
# >epoch=800, lrate=0.0001, error=4.201
# >epoch=801, lrate=0.0001, error=4.197
# >epoch=802, lrate=0.0001, error=4.193
# >epoch=803, lrate=0.0001, error=4.189
# >epoch=804, lrate=0.0001, error=4.185
# >epoch=805, lrate=0.0001, error=4.181
# >epoch=806, lrate=0.0001, error=4.177
# >epoch=807, lrate=0.0001, error=4.173
# >epoch=808, lrate=0.0001, error=4.169
# >epoch=809, lrate=0.0001, error=4.165
# >epoch=810, lrate=0.0001, error=4.161
# >epoch=811, lrate=0.0001, error=4.157
# >epoch=812, lrate=0.0001, error=4.153
# >epoch=813, lrate=0.0001, error=4.149
# >epoch=814, lrate=0.0001, error=4.145
# >epoch=815, lrate=0.0001, error=4.142
# >epoch=816, lrate=0.0001, error=4.138
# >epoch=817, lrate=0.0001, error=4.134
# >epoch=818, lrate=0.0001, error=4.130
# >epoch=819, lrate=0.0001, error=4.126
# >epoch=820, lrate=0.0001, error=4.122
# >epoch=821, lrate=0.0001, error=4.119
# >epoch=822, lrate=0.0001, error=4.115
# >epoch=823, lrate=0.0001, error=4.111
# >epoch=824, lrate=0.0001, error=4.107
# >epoch=825, lrate=0.0001, error=4.103
# >epoch=826, lrate=0.0001, error=4.100
# >epoch=827, lrate=0.0001, error=4.096
# >epoch=828, lrate=0.0001, error=4.092
# >epoch=829, lrate=0.0001, error=4.089
# >epoch=830, lrate=0.0001, error=4.085
# >epoch=831, lrate=0.0001, error=4.081
# >epoch=832, lrate=0.0001, error=4.077
# >epoch=833, lrate=0.0001, error=4.074
# >epoch=834, lrate=0.0001, error=4.070
# >epoch=835, lrate=0.0001, error=4.066
# >epoch=836, lrate=0.0001, error=4.063
# >epoch=837, lrate=0.0001, error=4.059
# >epoch=838, lrate=0.0001, error=4.056
# >epoch=839, lrate=0.0001, error=4.052
# >epoch=840, lrate=0.0001, error=4.048
# >epoch=841, lrate=0.0001, error=4.045
# >epoch=842, lrate=0.0001, error=4.041
# >epoch=843, lrate=0.0001, error=4.038
# >epoch=844, lrate=0.0001, error=4.034
# >epoch=845, lrate=0.0001, error=4.031
# >epoch=846, lrate=0.0001, error=4.027
# >epoch=847, lrate=0.0001, error=4.023
# >epoch=848, lrate=0.0001, error=4.020
# >epoch=849, lrate=0.0001, error=4.016
# >epoch=850, lrate=0.0001, error=4.013
# >epoch=851, lrate=0.0001, error=4.009
# >epoch=852, lrate=0.0001, error=4.006
# >epoch=853, lrate=0.0001, error=4.003
# >epoch=854, lrate=0.0001, error=3.999
# >epoch=855, lrate=0.0001, error=3.996
# >epoch=856, lrate=0.0001, error=3.992
# >epoch=857, lrate=0.0001, error=3.989
# >epoch=858, lrate=0.0001, error=3.985
# >epoch=859, lrate=0.0001, error=3.982
# >epoch=860, lrate=0.0001, error=3.979
# >epoch=861, lrate=0.0001, error=3.975
# >epoch=862, lrate=0.0001, error=3.972
# >epoch=863, lrate=0.0001, error=3.968
# >epoch=864, lrate=0.0001, error=3.965
# >epoch=865, lrate=0.0001, error=3.962
# >epoch=866, lrate=0.0001, error=3.958
# >epoch=867, lrate=0.0001, error=3.955
# >epoch=868, lrate=0.0001, error=3.952
# >epoch=869, lrate=0.0001, error=3.948
# >epoch=870, lrate=0.0001, error=3.945
# >epoch=871, lrate=0.0001, error=3.942
# >epoch=872, lrate=0.0001, error=3.939
# >epoch=873, lrate=0.0001, error=3.935
# >epoch=874, lrate=0.0001, error=3.932
# >epoch=875, lrate=0.0001, error=3.929
# >epoch=876, lrate=0.0001, error=3.926
# >epoch=877, lrate=0.0001, error=3.922
# >epoch=878, lrate=0.0001, error=3.919
# >epoch=879, lrate=0.0001, error=3.916
# >epoch=880, lrate=0.0001, error=3.913
# >epoch=881, lrate=0.0001, error=3.909
# >epoch=882, lrate=0.0001, error=3.906
# >epoch=883, lrate=0.0001, error=3.903
# >epoch=884, lrate=0.0001, error=3.900
# >epoch=885, lrate=0.0001, error=3.897
# >epoch=886, lrate=0.0001, error=3.894
# >epoch=887, lrate=0.0001, error=3.890
# >epoch=888, lrate=0.0001, error=3.887
# >epoch=889, lrate=0.0001, error=3.884
# >epoch=890, lrate=0.0001, error=3.881
# >epoch=891, lrate=0.0001, error=3.878
# >epoch=892, lrate=0.0001, error=3.875
# >epoch=893, lrate=0.0001, error=3.872
# >epoch=894, lrate=0.0001, error=3.869
# >epoch=895, lrate=0.0001, error=3.866
# >epoch=896, lrate=0.0001, error=3.863
# >epoch=897, lrate=0.0001, error=3.860
# >epoch=898, lrate=0.0001, error=3.856
# >epoch=899, lrate=0.0001, error=3.853
# >epoch=900, lrate=0.0001, error=3.850
# >epoch=901, lrate=0.0001, error=3.847
# >epoch=902, lrate=0.0001, error=3.844
# >epoch=903, lrate=0.0001, error=3.841
# >epoch=904, lrate=0.0001, error=3.838
# >epoch=905, lrate=0.0001, error=3.835
# >epoch=906, lrate=0.0001, error=3.832
# >epoch=907, lrate=0.0001, error=3.829
# >epoch=908, lrate=0.0001, error=3.827
# >epoch=909, lrate=0.0001, error=3.824
# >epoch=910, lrate=0.0001, error=3.821
# >epoch=911, lrate=0.0001, error=3.818
# >epoch=912, lrate=0.0001, error=3.815
# >epoch=913, lrate=0.0001, error=3.812
# >epoch=914, lrate=0.0001, error=3.809
# >epoch=915, lrate=0.0001, error=3.806
# >epoch=916, lrate=0.0001, error=3.803
# >epoch=917, lrate=0.0001, error=3.800
# >epoch=918, lrate=0.0001, error=3.797
# >epoch=919, lrate=0.0001, error=3.795
# >epoch=920, lrate=0.0001, error=3.792
# >epoch=921, lrate=0.0001, error=3.789
# >epoch=922, lrate=0.0001, error=3.786
# >epoch=923, lrate=0.0001, error=3.783
# >epoch=924, lrate=0.0001, error=3.780
# >epoch=925, lrate=0.0001, error=3.778
# >epoch=926, lrate=0.0001, error=3.775
# >epoch=927, lrate=0.0001, error=3.772
# >epoch=928, lrate=0.0001, error=3.769
# >epoch=929, lrate=0.0001, error=3.766
# >epoch=930, lrate=0.0001, error=3.764
# >epoch=931, lrate=0.0001, error=3.761
# >epoch=932, lrate=0.0001, error=3.758
# >epoch=933, lrate=0.0001, error=3.755
# >epoch=934, lrate=0.0001, error=3.753
# >epoch=935, lrate=0.0001, error=3.750
# >epoch=936, lrate=0.0001, error=3.747
# >epoch=937, lrate=0.0001, error=3.744
# >epoch=938, lrate=0.0001, error=3.742
# >epoch=939, lrate=0.0001, error=3.739
# >epoch=940, lrate=0.0001, error=3.736
# >epoch=941, lrate=0.0001, error=3.734
# >epoch=942, lrate=0.0001, error=3.731
# >epoch=943, lrate=0.0001, error=3.728
# >epoch=944, lrate=0.0001, error=3.726
# >epoch=945, lrate=0.0001, error=3.723
# >epoch=946, lrate=0.0001, error=3.720
# >epoch=947, lrate=0.0001, error=3.718
# >epoch=948, lrate=0.0001, error=3.715
# >epoch=949, lrate=0.0001, error=3.712
# >epoch=950, lrate=0.0001, error=3.710
# >epoch=951, lrate=0.0001, error=3.707
# >epoch=952, lrate=0.0001, error=3.705
# >epoch=953, lrate=0.0001, error=3.702
# >epoch=954, lrate=0.0001, error=3.699
# >epoch=955, lrate=0.0001, error=3.697
# >epoch=956, lrate=0.0001, error=3.694
# >epoch=957, lrate=0.0001, error=3.692
# >epoch=958, lrate=0.0001, error=3.689
# >epoch=959, lrate=0.0001, error=3.687
# >epoch=960, lrate=0.0001, error=3.684
# >epoch=961, lrate=0.0001, error=3.681
# >epoch=962, lrate=0.0001, error=3.679
# >epoch=963, lrate=0.0001, error=3.676
# >epoch=964, lrate=0.0001, error=3.674
# >epoch=965, lrate=0.0001, error=3.671
# >epoch=966, lrate=0.0001, error=3.669
# >epoch=967, lrate=0.0001, error=3.666
# >epoch=968, lrate=0.0001, error=3.664
# >epoch=969, lrate=0.0001, error=3.661
# >epoch=970, lrate=0.0001, error=3.659
# >epoch=971, lrate=0.0001, error=3.656
# >epoch=972, lrate=0.0001, error=3.654
# >epoch=973, lrate=0.0001, error=3.652
# >epoch=974, lrate=0.0001, error=3.649
# >epoch=975, lrate=0.0001, error=3.647
# >epoch=976, lrate=0.0001, error=3.644
# >epoch=977, lrate=0.0001, error=3.642
# >epoch=978, lrate=0.0001, error=3.639
# >epoch=979, lrate=0.0001, error=3.637
# >epoch=980, lrate=0.0001, error=3.635
# >epoch=981, lrate=0.0001, error=3.632
# >epoch=982, lrate=0.0001, error=3.630
# >epoch=983, lrate=0.0001, error=3.627
# >epoch=984, lrate=0.0001, error=3.625
# >epoch=985, lrate=0.0001, error=3.623
# >epoch=986, lrate=0.0001, error=3.620
# >epoch=987, lrate=0.0001, error=3.618
# >epoch=988, lrate=0.0001, error=3.616
# >epoch=989, lrate=0.0001, error=3.613
# >epoch=990, lrate=0.0001, error=3.611
# >epoch=991, lrate=0.0001, error=3.609
# >epoch=992, lrate=0.0001, error=3.606
# >epoch=993, lrate=0.0001, error=3.604
# >epoch=994, lrate=0.0001, error=3.602
# >epoch=995, lrate=0.0001, error=3.599
# >epoch=996, lrate=0.0001, error=3.597
# >epoch=997, lrate=0.0001, error=3.595
# >epoch=998, lrate=0.0001, error=3.593
# >epoch=999, lrate=0.0001, error=3.590
# Coef of train [19.375979703464306, 0.9439929876465684]
# Coef of test [14.847975694503432, 1.7434039636818004]
# Cost of Trainset is 2.6911513164905414
# Cost of Testset is 3.590278792119387

# %%
print(len(X_))
print(len(X_test))
print(y_train)

# %%
samples=len(dataset)
m=[]
n=[]
y_predict=[]
for i in range(samples):
    m.append(dataset[i][0])
    n.append(dataset[i][1])
    q=coef[0] + coef[1]*m[i]
    y_predict.append(q)
    

pylab.plot(m,n,'o')
pylab.plot(m,y_predict,'k-')
pylab.show()
print(coef)
# Out:
# [19.505796504369826, 0.9115791189577349]
